# %%
import pandas as pd
from database_handler import execute_query,create_connection,return_data_as_df
from lookups import InputTypes

db_session = create_connection()
query = """ SELECT * FROM dw_reporting.dim_gdp_all_measures
 """

df = return_data_as_df(query,InputTypes.SQL,db_session)
df
# Out:
# c:\Users\user\OneDrive\Documents\SE_Factory\FSD\Final_Project\usa_recession_analysis\database_handler.py:64: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return_dataframe = pd.read_sql_query(con= db_session, sql= file_executor)
#           date        gdp      pce      gpdi    netexp      gcec     impgs
# 0   2007-01-01  16611.690  28716.4  2664.295  -739.273  3299.115  2317.264
# 1   2007-04-01  16713.314  29036.2  2699.217  -745.806  3329.139  2368.569
# 2   2007-07-01  16809.587  29395.1  2685.969  -728.954  3344.222  2414.664
# 3   2007-10-01  16915.191  29811.4  2642.560  -729.699  3370.950  2480.413
# 4   2008-01-01  16843.003  30013.4  2563.701  -771.248  3378.654  2584.568
# 5   2008-04-01  16943.291  30389.7  2540.595  -776.404  3407.753  2681.686
# 6   2008-07-01  16854.295  30477.2  2498.242  -787.354  3435.100  2709.569
# 7   2008-10-01  16485.350  29720.8  2307.915  -628.474  3458.839  2328.779
# 8   2009-01-01  16298.262  29444.9  2014.878  -420.992  3498.103  1932.761
# 9   2009-04-01  16269.145  29416.5  1863.650  -358.368  3549.027  1879.461
# 10  2009-07-01  16326.281  29818.2  1841.416  -423.998  3558.540  2018.722
# 11  2009-10-01  16502.754  30015.0  1998.710  -473.254  3565.188  2176.763
# 12  2010-01-01  16582.710  30305.5  2038.161  -509.192  3549.775  2269.069
# 13  2010-04-01  16743.162  30624.4  2148.795  -542.514  3560.566  2362.255
# 14  2010-07-01  16872.266  30902.3  2236.495  -553.943  3535.371  2431.195
# 15  2010-10-01  16960.864  31291.0  2238.440  -523.586  3512.905  2495.702
# 16  2011-01-01  16920.632  31674.6  2205.962  -568.476  3469.798  2608.884
# 17  2011-04-01  17035.114  32019.1  2297.352  -581.092  3446.079  2697.224
# 18  2011-07-01  17031.313  32265.1  2322.840  -567.111  3396.917  2723.903
# 19  2011-10-01  17222.583  32427.5  2504.095  -601.788  3394.613  2751.911
# 20  2012-01-01  17367.010  32877.9  2567.750  -602.271  3380.162  2792.253
# 21  2012-04-01  17444.525  33015.1  2636.863  -565.241  3362.330  2780.827
# 22  2012-07-01  17469.650  33178.1  2644.119  -523.083  3357.201  2750.817
# 23  2012-10-01  17489.852  33497.0  2638.282  -515.874  3324.137  2753.373
# 24  2013-01-01  17662.400  33833.0  2746.420  -499.348  3293.099  2755.277
# 25  2013-04-01  17709.671  33947.1  2780.242  -498.380  3288.858  2759.783
# 26  2013-07-01  17860.450  34225.1  2892.354  -482.067  3272.825  2767.183
# 27  2013-10-01  18016.147  34653.7  2934.291  -434.019  3247.579  2783.259
# 28  2014-01-01  17953.974  34938.0  2922.765  -510.088  3233.646  2853.690
# 29  2014-04-01  18185.911  35431.3  3059.096  -505.404  3238.033  2900.572
# 30  2014-07-01  18406.941  35879.5  3142.047  -489.357  3259.900  2888.549
# 31  2014-10-01  18500.031  36244.7  3172.016  -530.751  3257.472  2906.969
# 32  2015-01-01  18666.621  36359.4  3282.283  -526.432  3277.170  2825.476
# 33  2015-04-01  18782.243  36792.4  3291.104  -509.527  3309.301  2809.968
# 34  2015-07-01  18857.418  37147.5  3303.660  -538.082  3326.769  2798.806
# 35  2015-10-01  18892.206  37270.1  3276.879  -523.238  3341.055  2745.517
# 36  2016-01-01  19001.690  37569.5  3244.317  -511.682  3371.646  2693.639
# 37  2016-04-01  19062.709  37995.4  3246.381  -489.370  3369.042  2711.306
# 38  2016-07-01  19197.938  38391.4  3261.571  -481.229  3383.696  2751.229
# 39  2016-10-01  19304.352  38765.9  3360.952  -530.806  3389.649  2799.145
# 40  2017-01-01  19398.343  39292.0  3363.101  -533.420  3380.244  2873.148
# 41  2017-04-01  19506.949  39566.3  3432.968  -553.499  3389.811  2903.180
# 42  2017-07-01  19660.766  39975.2  3500.142  -531.498  3394.009  2916.022
# 43  2017-10-01  19882.352  40654.2  3574.446  -554.897  3424.498  3034.004
# 44  2018-01-01  20044.077  41235.2  3645.635  -576.031  3431.709  3093.299
# 45  2018-04-01  20150.476  41673.8  3662.727  -543.823  3456.309  3105.995
# 46  2018-07-01  20276.154  42006.6  3788.692  -618.246  3483.628  3153.747
# 47  2018-10-01  20304.874  42297.6  3802.028  -634.207  3488.352  3171.622
# 48  2019-01-01  20415.150  42444.0  3850.171  -598.587  3535.387  3142.693
# 49  2019-04-01  20584.528  43010.3  3894.868  -615.022  3588.929  3160.379
# 50  2019-07-01  20817.581  43553.1  3939.338  -584.258  3629.001  3116.653
# 51  2019-10-01  20951.088  44003.9  3885.228  -516.146  3652.085  3048.089
# 52  2020-01-01  20665.553  43419.4  3807.759  -518.021  3691.924  2934.121
# 53  2020-04-01  19034.830  39506.8  3254.272  -531.137  3768.904  2342.488
# 54  2020-07-01  20511.785  43368.5  3891.227  -695.747  3709.691  2802.324
# 55  2020-10-01  20724.128  44180.1  4040.153  -760.659  3691.493  3027.081
# 56  2021-01-01  20990.541  45653.1  4031.066  -792.417  3743.069  3175.205
# 57  2021-04-01  21309.544  47852.6  4013.283  -831.972  3701.847  3330.241
# 58  2021-07-01  21483.083  48855.3  4226.608  -884.277  3688.204  3450.245
# 59  2021-10-01  21847.602  50154.6  4594.048  -924.289  3685.796  3677.415
# 60  2022-01-01  21738.871  51091.9  4766.754 -1089.677  3658.819  3927.291
# 61  2022-04-01  21708.160  52245.3  4739.049 -1025.567  3641.161  4069.839
# 62  2022-07-01  21851.134  53052.6  4724.621  -892.026  3666.982  3976.524
# 63  2022-10-01  21989.981  53751.2  4796.162  -877.204  3714.800  3891.004
# 64  2023-01-01  22112.329  54808.7  4725.828  -825.687  3758.768  3890.491
# 65  2023-04-01  22225.350  55257.0  4780.290  -806.093  3789.786  3767.851

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# %%
# Assuming your data is in a DataFrame named 'df'
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# %%
# You can use the adfuller function from statsmodels for the ADF test
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['gdp'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: 0.6853868216176305
# p-value: 0.9895416810729587

# %%
# Example of differencing
df['gdp_diff'] = df['gdp'].diff()

# %%
pd.set_option('display.max_rows', None)

# %%
df['gdp_diff']
# Out:
# date
# 2007-01-01         NaN
# 2007-04-01     101.624
# 2007-07-01      96.273
# 2007-10-01     105.604
# 2008-01-01     -72.188
# 2008-04-01     100.288
# 2008-07-01     -88.996
# 2008-10-01    -368.945
# 2009-01-01    -187.088
# 2009-04-01     -29.117
# 2009-07-01      57.136
# 2009-10-01     176.473
# 2010-01-01      79.956
# 2010-04-01     160.452
# 2010-07-01     129.104
# 2010-10-01      88.598
# 2011-01-01     -40.232
# 2011-04-01     114.482
# 2011-07-01      -3.801
# 2011-10-01     191.270
# 2012-01-01     144.427
# 2012-04-01      77.515
# 2012-07-01      25.125
# 2012-10-01      20.202
# 2013-01-01     172.548
# 2013-04-01      47.271
# 2013-07-01     150.779
# 2013-10-01     155.697
# 2014-01-01     -62.173
# 2014-04-01     231.937
# 2014-07-01     221.030
# 2014-10-01      93.090
# 2015-01-01     166.590
# 2015-04-01     115.622
# 2015-07-01      75.175
# 2015-10-01      34.788
# 2016-01-01     109.484
# 2016-04-01      61.019
# 2016-07-01     135.229
# 2016-10-01     106.414
# 2017-01-01      93.991
# 2017-04-01     108.606
# 2017-07-01     153.817
# 2017-10-01     221.586
# 2018-01-01     161.725
# 2018-04-01     106.399
# 2018-07-01     125.678
# 2018-10-01      28.720
# 2019-01-01     110.276
# 2019-04-01     169.378
# 2019-07-01     233.053
# 2019-10-01     133.507
# 2020-01-01    -285.535
# 2020-04-01   -1630.723
# 2020-07-01    1476.955
# 2020-10-01     212.343
# 2021-01-01     266.413
# 2021-04-01     319.003
# 2021-07-01     173.539
# 2021-10-01     364.519
# 2022-01-01    -108.731
# 2022-04-01     -30.711
# 2022-07-01     142.974
# 2022-10-01     138.847
# 2023-01-01     122.348
# 2023-04-01     113.021
# Name: gdp_diff, dtype: float64

# %%
result_diff = adfuller(df['gdp_diff'].dropna())
print('ADF Statistic:', result_diff[0])
print('p-value:', result_diff[1])
# Out:
# ADF Statistic: -6.869334573493591
# p-value: 1.5299063683304448e-09

# %%
pd.reset_option('display.max_rows')

# Example of ACF and PACF plots
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

plot_acf(df['gdp_diff'].dropna(), lags=5, ax=ax1)
plot_pacf(df['gdp_diff'].dropna(), lags=5, ax=ax2)

plt.show()

# %%
# Example of fitting an ARIMA model
order = (3, 1, 2)  # Replace p, d, q with the determined values
model = ARIMA(df['gdp'], order=order)
fit_model = model.fit()
# Out:
# c:\Users\user\anaconda3\envs\sefactory_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# c:\Users\user\anaconda3\envs\sefactory_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# c:\Users\user\anaconda3\envs\sefactory_env\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

# Example of making predictions
future_date = datetime(2023,7,1)

future_date
# Out:
# datetime.datetime(2023, 7, 1, 0, 0)

# %%
future_dates = []
for _ in range(12):
    future_date += relativedelta(months=3)
    future_dates.append(future_date)
future_dates
# Out:
# [datetime.datetime(2023, 10, 1, 0, 0),
#  datetime.datetime(2024, 1, 1, 0, 0),
#  datetime.datetime(2024, 4, 1, 0, 0),
#  datetime.datetime(2024, 7, 1, 0, 0),
#  datetime.datetime(2024, 10, 1, 0, 0),
#  datetime.datetime(2025, 1, 1, 0, 0),
#  datetime.datetime(2025, 4, 1, 0, 0),
#  datetime.datetime(2025, 7, 1, 0, 0),
#  datetime.datetime(2025, 10, 1, 0, 0),
#  datetime.datetime(2026, 1, 1, 0, 0),
#  datetime.datetime(2026, 4, 1, 0, 0),
#  datetime.datetime(2026, 7, 1, 0, 0)]

# %%
forecast = fit_model.get_forecast(steps=len(future_dates))
forecast_index = pd.DatetimeIndex(future_dates)

forecast_values = forecast.predicted_mean
forecast_df = pd.DataFrame({'GDP Forecast': forecast_values}, index=forecast_index)

print(forecast_df)
# Out:
#             GDP Forecast
# 2023-10-01  22392.072578
# 2024-01-01  22476.570941
# 2024-04-01  22562.125824
# 2024-07-01  22646.705949
# 2024-10-01  22732.248641
# 2025-01-01  22816.830597
# 2025-04-01  22902.372669
# 2025-07-01  22986.954782
# 2025-10-01  23072.496476
# 2026-01-01  23157.078711
# 2026-04-01  23242.620033
# 2026-07-01           NaN
