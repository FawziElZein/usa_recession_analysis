# %%
import os
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import pandas as pd
import re
import nltk
from urllib.request import urlopen, Request
from urllib.parse import urlparse
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
def preprocess_text(text):
    # Preprocessing function
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()

    if isinstance(text, str):
        # remove punctuation and special characters
        text = re.sub(r'[^\w\s]', '', text)  # r'[^\w\s]' : matches any character that is not a word character (alphanumeric or underscore) or a whitespace character
        # convert to lowercase
        text = text.lower()
        # tokenize text
        tokens = nltk.word_tokenize(text)
        # remove stop words
        tokens = [token for token in tokens if token not in stop_words]
        # lemmatize text
        tokens = [lemmatizer.lemmatize(token) for token in tokens]
        # join tokens back into text
        text = ' '.join(tokens)
    return text

# %%
web_url = 'https://finviz.com/quote.ashx?t='

news_tables = {}
# tickers = ['AMZN', 'GOOG', 'TSLA']
tickers = ['AMZN']

for tick in tickers:
    url = web_url + tick
    req = Request(url=url,headers={"User-Agent": "Chrome"}) 
    response = urlopen(req)    
    html = BeautifulSoup(response,"html.parser")
    news_table = html.find(id='news-table')
    news_tables[tick] = news_table

# %%
news_tables['AMZN']

# %%
amazon = news_tables['AMZN']
amazon_tr = amazon.findAll('tr')

for x, table_row in enumerate(amazon_tr):
    a_text = table_row.a.text
    td_text = table_row.td.text
    print(a_text)
    print(td_text)
    if x == 3:
        break

# %%
#original code
news_list = []

for file_name, news_table in news_tables.items():
    for i in news_table.findAll('tr'):
        
        text = i.a.get_text() 
        
        date_scrape = i.td.text.split()
        
        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        else:
            date = date_scrape[0]
            time = date_scrape[1]

        tick = file_name.split('_')[0]
        
        news_list.append([tick, date, time, text])

# %%
#My version

news_list = []
count = 0
for file_name, news_table in news_tables.items():
    for i in news_table.findAll('tr'):
        print("count tr")
        print(count)
        count+=1
        text = i.a.get_text()
         
        date_scrape = i.td.text.split()
        
        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        else:
            date = date_scrape[0]
            time = date_scrape[1]

        tick = file_name.split('_')[0]
        try:
            url = i.a['href']
            parsed_url = urlparse(url)
            if parsed_url.netloc=='finance.yahoo.com':
                req = Request(url=url,headers={"User-Agent": "Chrome"}) 
                response = urlopen(req)
                if response.getcode() == 200:
                    html = BeautifulSoup(response,"html.parser")
                    print("title : ",i.a.get_text())

                    caas_body_div = html.find('div', class_='caas-body')

                    if caas_body_div: 
                        for p in caas_body_div.findAll('p'):
                            text += '\n' + p.text
                    # print("Content")
                    # print(text)
                    
                else:
                    print(f"Webscrapping failed: Unable to web scrape {url}",
                        response.status_code)
        except Exception as e:
            print(f"An error occurred: {str(e)}")
        finally:
            news_list.append([tick, date, time, text])
# Out:
# count tr
# 0
# title :  3 Little-Known Ways to Save Money This October
# count tr
# 1
# title :  Amazons SpaceX Duel Heats Up as Tardy Satellites Set to Fly
# count tr
# 2
# title :  Amazon's Prime Big Deal Days Start on Oct. 10. Here Are 4 Tips to Score the Best Deals
# count tr
# 3
# title :  Market Today: Mixed Results for Major Indices, Aehr Test Systems Beats Q1 Estimates, Beverage ...
# count tr
# 4
# title :  Amazon is offering free grocery delivery on orders exceeding $100
# count tr
# 5
# title :  Amazons largest cargo jet makes debut
# count tr
# 6
# title :  Growth in AI, the cloud means tech stocks are 'going up': Analyst
# count tr
# 7
# title :  3 Mistakes to Avoid During the Prime Day Frenzy
# count tr
# 8
# title :  How to watch the NFLs Thursday Night Football Week 5 of the 2023-2024 season live online for freeand without cable
# count tr
# 9
# title :  4 Tips for Getting the Most Out of Prime Day Sales
# count tr
# 10
# title :  Amazon Prime day sales event to kick off holiday deals: Expert
# count tr
# 11
# title :  3 Things I Would Never Ever Buy on Amazon Prime Day
# count tr
# 12
# title :  The 10 Richest People in the World
# count tr
# 13
# count tr
# 14
# title :  Amazon, Microsoft cloud services under investigation by UK regulators
# count tr
# 15
# title :  US and UK Regulators Are Going After Amazon And Microsoft
# count tr
# 16
# title :  Williams-Sonoma's (WSM) Pottery Barn Collaborates With WBDGCP
# count tr
# 17
# title :  Amazon Is Now An Advertising Juggernaut. Big Tech Rivals  And The Feds  Are Taking Notice.
# count tr
# 18
# title :  Disney Slashes Ticket Prices For Children, US Government Ceases Free Distribution Of Merck COVID Pill, UK Deep Dives Into Amazon And Microsoft's Cloud Power: Today's Top Stories
# count tr
# 19
# title :  Microsoft Joins Amazon in Antitrust Crosshairs. This Time Its About the Cloud.
# count tr
# 20
# count tr
# 21
# An error occurred: HTTP Error 404: Not Found
# count tr
# 22
# title :  This Big Tech Company Just Poured Billions More Into AI
# count tr
# 23
# title :  Tech Analyst Dan Ives Says 4 Secular Growth Trends Are a "Springboard for Growth Into 2024." These Stocks Could Profit Most.
# count tr
# 24
# title :  FANG Stocks News & Quotes: Facebook, Amazon, Netflix, Google
# count tr
# 25
# title :  Retail Stocks And E-Commerce News And Stocks To Watch
# count tr
# 26
# title :  U.S. online sales to grow 4.8% in crucial holiday season -report
# count tr
# 27
# title :  Is Amazon Stock Too Risky With an FTC Lawsuit Lingering?
# count tr
# 28
# title :  Ofcom calls for UK antitrust probe into Microsoft and Amazons cloud dominance
# count tr
# 29
# title :  Fears about Amazon and Microsoft cloud computing dominance trigger UK probe
# count tr
# 30
# title :  Here's 1 Key Investing Metric Where Apple and Google Trounce the Other Stocks in the $1 Trillion Club
# count tr
# 31
# title :  3 Top E-Commerce Stocks to Buy in October
# count tr
# 32
# count tr
# 33
# title :  Amazon, Microsoft Face UK Competition Probe Over Cloud Dominance
# count tr
# 34
# title :  Amazon disagrees with UK regulator over cloud hosting dominance
# count tr
# 35
# title :  Amazon, Microsoft Cloud Services Face UK Competition Probe
# count tr
# 36
# title :  Q1 2024 Tilray Brands Inc Earnings Call
# count tr
# 37
# title :  UPDATE 6-UK regulator asks for antitrust probe into Amazon, Microsoft cloud dominance
# count tr
# 38
# count tr
# 39
# title :  Amazon (AMZN) Outperforms Broader Market: What You Need to Know
# count tr
# 40
# count tr
# 41
# title :  FTC: Amazon had a secret project to raise prices
# count tr
# 42
# title :  Amazon's Prime Video ads will generate billions, analyst says
# count tr
# 43
# title :  15 Stocks Billionaire Seth Klarman Likes the Most Now
# count tr
# 44
# title :  Can CPGs sell on Amazon Marketplace profitably?
# count tr
# 45
# title :  Amazon's 'Project Nessie' algorithm was used to raise prices: Report
# count tr
# 46
# title :  Should You Do Your Holiday Shopping on Amazon Prime Day?
# count tr
# 47
# title :  Amazon's (AMZN) New Generative AI Efforts Boost AWS Offerings
# count tr
# 48
# title :  Matchmaking, Break-Ups, and a Survivor
# count tr
# 49
# title :  Are Banks Closed on Columbus Day/Indigenous Peoples' Day in 2023?
# count tr
# 50
# title :  Is Nvidia Stock About to Do the Unthinkable?
# count tr
# 51
# title :  5 Amazing Amazon Prime Deals for October 2023
# count tr
# 52
# title :  3 Things About Amazon That Smart Investors Know
# count tr
# 53
# title :  Prominent ChatGPT rival eyes $30 billion valuation with new Big Tech investment
# count tr
# 54
# count tr
# 55
# title :  Costco Could Crush Amazon in This Huge Emerging Market
# count tr
# 56
# title :  Get Over $35 Back Before Amazon Prime Big Deal Days
# count tr
# 57
# title :  Is Amazon Investing Too Much in Growth?
# count tr
# 58
# title :  1 Stock-Split Stock to Buy Hand Over Fist in October and 1 to Avoid
# count tr
# 59
# title :  20 Most Searched Stocks on Google
# count tr
# 60
# title :  Market Today: Tech Stocks Under Pressure, House Ousts McCarthy, and FTC Accuses Amazon of Price ...
# count tr
# 61
# title :  Consumers plan on spending more this holiday season: Survey
# count tr
# 62
# title :  Amazon downsizes cargo operations at German airport
# count tr
# 63
# title :  Amazon Used Secret Project Nessie Algorithm to Raise Prices
# count tr
# 64
# title :  Spotify Makes Audiobooks Free to Paid Subscribers
# count tr
# 65
# title :  Prime Day Is Coming on Oct. 10. Here's How to Make Sure You Don't Miss the Hottest Deals
# count tr
# 66
# title :  Space Missions to Watch in October 2023: Amazon Kuiper, NASA Science Probe, SpaceX
# count tr
# 67
# title :  Why Amazon Stock Dropped on Tuesday
# count tr
# 68
# title :  Prime Video ads could add billions to Amazon's bottom line: Analyst
# count tr
# 69
# title :  Its Musk vs. Bezos as Amazons Kuiper, a Starlink Rival, Goes to Space Soon
# count tr
# 70
# title :  Netflix considers raising price of ad-free tier: Report
# count tr
# 71
# title :  With Amazon Prime Day deals on fire, this tablet device is selling at a ridiculously low price
# count tr
# 72
# title :  Jeff Bezos targets Friday satellite launch in move against Elon Musk
# count tr
# 73
# title :  UK regulator to push for probe into Amazon, Microsoft cloud dominance
# count tr
# 74
# title :  Amazon Stock Is Under Pressure. Why Two Analysts Think You Should Be a Buyer.
# count tr
# 75
# title :  Williams-Sonoma's (WSM) Rejuvenation Opens New San Diego Store
# count tr
# 76
# title :  Amazon (AMZN) AWS' Clientele Expands With Telkomsel Deal
# count tr
# 77
# title :  3 Top Artificial Intelligence (AI) Stocks to Buy in October
# count tr
# 78
# title :  The Best Stocks to Invest $50,000 in Right Now
# count tr
# 79
# title :  Amazon Gets Sued by the FTC. Here's What I'm Doing With My Shares.
# count tr
# 80
# title :  When Is Amazon Prime Day?
# count tr
# 81
# title :  Can Amazon's $4 Billion Artificial Intelligence (AI) Investment Reaccelerate Its Cloud Business?
# count tr
# 82
# title :  Trying to Save Money? Use This Money Hack
# count tr
# 83
# title :  3 Stocks That Could Create Lasting Generational Wealth
# count tr
# 84
# title :  Better Buy: Amazon vs. Apple
# count tr
# 85
# count tr
# 86
# title :  SentinelOne (S) Benefits from Robust Portfolio, Partner Base Strength
# count tr
# 87
# title :  Why Amazon Stock Bumped Higher on Monday
# count tr
# 88
# count tr
# 89
# title :  Why Amazon Could Have An Advertising Edge Among Streamers
# count tr
# 90
# title :  Falling Yields, Valuations Could Lift Mega-Cap Tech Stocks in Q4
# count tr
# 91
# count tr
# 92
# title :  Amazon sends a warning customers need to know about
# count tr
# 93
# title :  Hollywood actors to resume talks with studios after conclusion of writers' strike
# count tr
# 94
# title :  Hollywood actors resume talks with studios after conclusion of writers' strike
# count tr
# 95
# title :  Amazon.com Inc (AMZN): A Deep Dive into Financial Metrics and Competitive Strengths
# count tr
# 96
# title :  Amazon Is Bringing Ads to Prime Video. Its a Big Win for the Stock.
# count tr
# 97
# title :  Amazon (AMZN) Zoox is Set to Establish a Facility in East Bay
# count tr
# 98
# title :  Target's answer to Amazon Prime Days is here  these are the top deals
# count tr
# 99
# title :  My Top 10 Tech Stocks for October 2023

# %%
parsed_url
# Out:
# ParseResult(scheme='https', netloc='finance.yahoo.com', path='/m/2f0cbbf7-a8c6-381f-9451-acfd2e967348/my-top-10-tech-stocks-for.html', params='', query='', fragment='')

# %%
len(news_list)
# Out:
# 100

# %%
try:

    url = 'https://finance.yahoo.com/m/faab6fb7-c85c-32c9-a7bb-8ac838ea013b/3-little-known-ways-to-save.html'
    req = Request(url=url,headers={"User-Agent": "Chrome"}) 
    response = urlopen(req)
    print(response.getcode())
    if response.getcode() == 200:
        html = BeautifulSoup(response,"html.parser")
        print(html)
except Exception as e:
    print(e)
# response = urlopen(req)

# %%
len(news_table.findAll('tr'))

# %%
vader = SentimentIntensityAnalyzer()

processed_text = preprocess_text(text)
vader.polarity_scores(processed_text)

# %%
news_table = news_tables['AMZN']

i = news_table.findAll('tr')[1]
    
text = i.a.get_text() 
url = i.a['href']

req = Request(url=url,headers={"User-Agent": "Chrome"}) 
response = urlopen(req)
html = BeautifulSoup(response,"html.parser")
text_content = html.get_text()
print(text_content)

# %%
vader = SentimentIntensityAnalyzer()

vader.polarity_scores(text_content)

# %%
caas_body_div = html.find('div', class_='caas-body')
text = ""
for p in caas_body_div.findAll('p'):
    text += p.text + '\n'

print(text)

# %%
news_list

# %%
from datetime import datetime
def parse_today_as_date(value):
    if value == 'Today':
        return datetime.now().date()
    else:
        return value

# %%
vader = SentimentIntensityAnalyzer()

columns = ['ticker', 'date', 'time', 'text']

news_df = pd.DataFrame(news_list, columns=columns)

scores = news_df['text'].apply(preprocess_text).apply(vader.polarity_scores).tolist()

scores_df = pd.DataFrame(scores)

news_df = news_df.join(scores_df)

news_df['date'] = news_df['date'].apply(parse_today_as_date)

# %%
news_df
# Out:
#    ticker       date     time  \
# 0    AMZN  Oct-05-23  07:52PM
# 1    AMZN  Oct-05-23  06:38PM
# 2    AMZN  Oct-05-23  06:00PM
# 3    AMZN  Oct-05-23  05:30PM
# 4    AMZN  Oct-05-23  05:01PM
# ..    ...        ...      ...
# 95   AMZN  Oct-02-23  01:02PM
# 96   AMZN  Oct-02-23  11:57AM
# 97   AMZN  Oct-02-23  11:34AM
# 98   AMZN  Oct-02-23  11:18AM
# 99   AMZN  Oct-02-23  10:52AM
#
#                                                  text    neg    neu    pos  \
# 0   3 Little-Known Ways to Save Money This October...  0.058  0.628  0.314
# 1   Amazons SpaceX Duel Heats Up as Tardy Satellit...  0.050  0.826  0.124
# 2   Amazon's Prime Big Deal Days Start on Oct. 10....  0.000  0.718  0.282
# 3   Market Today: Mixed Results for Major Indices,...  0.082  0.798  0.121
# 4   Amazon is offering free grocery delivery on or...  0.107  0.763  0.130
# ..                                                ...    ...    ...    ...
# 95  Amazon.com Inc (AMZN): A Deep Dive into Financ...  0.032  0.704  0.264
# 96  Amazon Is Bringing Ads to Prime Video. Its a B...  0.068  0.685  0.247
# 97  Amazon (AMZN) Zoox is Set to Establish a Facil...  0.006  0.781  0.213
# 98  Target's answer to Amazon Prime Days is here  ...  0.000  0.811  0.189
# 99  My Top 10 Tech Stocks for October 2023\nIn tod...  0.000  0.673  0.327
#
#     compound
# 0     0.8750
# 1     0.9899
# 2     0.8957
# 3     0.9017
# 4     0.7096
# ..       ...
# 95    0.9988
# 96    0.6369
# 97    0.9968
# 98    0.3612
# 99    0.8910
#
# [100 rows x 8 columns]

# %%
import yfinance as yf

amazon_data = yf.download("AMZN", start="2022-01-01", end="2023-10-10")
print(amazon_data)
